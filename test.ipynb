# %%
import pandas
data = pandas.read_csv("datasets/Hypertension-risk-model-main.csv")
data
# Out:
#       gender  age  currentSmoker  cigsPerDay  BPMeds  diabetes  totChol  \
# 0          1   39              0           0       0         0      195
# 1          0   46              0           0       0         0      250
# 2          1   48              1          20       0         0      245
# 3          0   61              1          30       0         0      225
# 4          0   46              1          23       0         0      285
# ...      ...  ...            ...         ...     ...       ...      ...
# 4235       0   48              1          20       0         0      248
# 4236       0   44              1          15       0         0      210
# 4237       0   52              0           0       0         0      269
# 4238       1   40              0           0       0         0      185
# 4239       0   39              1          30       0         0      196
#
#       sysBP  diaBP    BMI  heartRate  glucose  Risk
# 0     106.0   70.0  26.97         80       77     0
# 1     121.0   81.0  28.73         95       76     0
# 2     127.5   80.0  25.34         75       70     0
# 3     150.0   95.0  28.58         65      103     1
# 4     130.0   84.0  23.10         85       85     0
# ...     ...    ...    ...        ...      ...   ...
# 4235  131.0   72.0  22.00         84       86     0
# 4236  126.5   87.0  19.16         86        0     0
# 4237  133.5   83.0  21.47         80      107     0
# 4238  141.0   98.0  25.60         67       72     1
# 4239  133.0   86.0  20.91         85       80     0
#
# [4240 rows x 13 columns]

# %%
data.describe()
# Out:
#             gender          age  currentSmoker   cigsPerDay       BPMeds  \
# count  4240.000000  4240.000000    4240.000000  4240.000000  4240.000000
# mean      0.429245    49.580189       0.494104     8.944340     0.029245
# std       0.495027     8.572942       0.500024    11.904777     0.168513
# min       0.000000    32.000000       0.000000     0.000000     0.000000
# 25%       0.000000    42.000000       0.000000     0.000000     0.000000
# 50%       0.000000    49.000000       0.000000     0.000000     0.000000
# 75%       1.000000    56.000000       1.000000    20.000000     0.000000
# max       1.000000    70.000000       1.000000    70.000000     1.000000
#
#           diabetes      totChol        sysBP        diaBP          BMI  \
# count  4240.000000  4240.000000  4240.000000  4240.000000  4240.000000
# mean      0.025708   233.908255   132.354599    82.897759    25.685184
# std       0.158280    51.166237    22.033300    11.910394     4.420501
# min       0.000000     0.000000    83.500000    48.000000     0.000000
# 25%       0.000000   205.000000   117.000000    75.000000    23.050000
# 50%       0.000000   233.000000   128.000000    82.000000    25.380000
# 75%       0.000000   262.000000   144.000000    90.000000    28.032500
# max       1.000000   696.000000   295.000000   142.500000    56.800000
#
#          heartRate      glucose         Risk
# count  4240.000000  4240.000000  4240.000000
# mean     75.861085    74.463208     0.310613
# std      12.080265    32.862256     0.462799
# min       0.000000     0.000000     0.000000
# 25%      68.000000    68.000000     0.000000
# 50%      75.000000    77.000000     0.000000
# 75%      83.000000    85.000000     1.000000
# max     143.000000   394.000000     1.000000

# %%
data.isnull().sum()
# Out:
# gender           0
# age              0
# currentSmoker    0
# cigsPerDay       0
# BPMeds           0
# diabetes         0
# totChol          0
# sysBP            0
# diaBP            0
# BMI              0
# heartRate        0
# glucose          0
# Risk             0
# dtype: int64

# %%
data['Risk'].replace({1:"At Risk",0:"Not at Risk"},inplace=True)
data['gender'].replace({"Male":1,"Female":0},inplace=True)
data['currentSmoker'].replace({"Yes":1,"No":0},inplace=True)
data['diabetes'].replace({"Yes":1,"No":0},inplace=True)
data['BPMeds'].replace({"Yes":1,"No":0},inplace=True)
# Out:
# /tmp/ipykernel_9085/2789147043.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Risk'].replace({1:"At Risk",0:"Not at Risk"},inplace=True)
# /tmp/ipykernel_9085/2789147043.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['gender'].replace({"Male":1,"Female":0},inplace=True)
# /tmp/ipykernel_9085/2789147043.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['currentSmoker'].replace({"Yes":1,"No":0},inplace=True)
# /tmp/ipykernel_9085/2789147043.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['diabetes'].replace({"Yes":1,"No":0},inplace=True)
# /tmp/ipykernel_9085/2789147043.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['BPMeds'].replace({"Yes":1,"No":0},inplace=True)

# %%
array = data.values
X = array[:,0:12]
X
Y =array[:,12]
Y
# Out:
# array(['Not at Risk', 'Not at Risk', 'Not at Risk', ..., 'Not at Risk',
#        'At Risk', 'Not at Risk'], dtype=object)

# %%
from sklearn  import model_selection
# X_train,X_Test,Y_Test,X_Test = model_selection.train_test_split(X,Y ,test_size=0.3,random_state=42)
X_train,X_test,Y_train,Y_test = model_selection.train_test_split(X, Y, test_size=0.1,random_state=42)
X_train
Y_train
# Out:
# array(['Not at Risk', 'At Risk', 'Not at Risk', ..., 'At Risk',
#        'Not at Risk', 'Not at Risk'], dtype=object)

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

# %%
model = SVC()
model.fit(X_train, Y_train)
# Out:
# SVC()

# %%
predictions = model.predict(X_test)
print(f"Model Predicted {predictions}")
# Out:
# Model Predicted ['Not at Risk' 'Not at Risk' 'Not at Risk' 'At Risk' 'Not at Risk'
#  'At Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk'
#  'At Risk' 'Not at Risk' 'At Risk' 'At Risk' 'Not at Risk' 'At Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'At Risk' 'Not at Risk'
#  'Not at Risk' 'At Risk' 'At Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'At Risk' 'Not at Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk'
#  'At Risk' 'At Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk' 'At Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'At Risk' 'Not at Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk' 'At Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'At Risk' 'At Risk' 'At Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'At Risk' 'Not at Risk' 'Not at Risk' 'At Risk'
#  'Not at Risk' 'At Risk' 'At Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk'
#  'At Risk' 'At Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'At Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk'
#  'At Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk' 'At Risk'
#  'Not at Risk' 'At Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'Not at Risk' 'At Risk' 'At Risk' 'At Risk' 'Not at Risk'
#  'Not at Risk' 'At Risk' 'At Risk' 'At Risk' 'Not at Risk' 'At Risk'
#  'At Risk' 'At Risk' 'At Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk'
#  'At Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk' 'At Risk'
#  'Not at Risk' 'At Risk' 'At Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'At Risk' 'Not at Risk' 'At Risk' 'At Risk' 'Not at Risk'
#  'Not at Risk' 'Not at Risk' 'At Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk' 'At Risk'
#  'Not at Risk' 'At Risk' 'Not at Risk' 'At Risk' 'Not at Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'At Risk' 'Not at Risk'
#  'Not at Risk' 'At Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'At Risk' 'Not at Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'At Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'At Risk' 'Not at Risk' 'Not at Risk' 'At Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'At Risk' 'Not at Risk'
#  'Not at Risk' 'At Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'At Risk' 'At Risk' 'Not at Risk' 'Not at Risk' 'At Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk'
#  'At Risk' 'Not at Risk' 'At Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'At Risk' 'At Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'At Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk' 'At Risk'
#  'Not at Risk' 'At Risk' 'Not at Risk' 'Not at Risk' 'At Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'Not at Risk' 'At Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'Not at Risk' 'At Risk' 'At Risk' 'At Risk' 'Not at Risk'
#  'At Risk' 'Not at Risk' 'At Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'At Risk' 'Not at Risk' 'At Risk' 'Not at Risk' 'At Risk'
#  'At Risk' 'Not at Risk' 'At Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk' 'At Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk'
#  'At Risk' 'Not at Risk' 'Not at Risk' 'At Risk' 'Not at Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk' 'At Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk' 'At Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'At Risk' 'Not at Risk'
#  'Not at Risk' 'Not at Risk' 'At Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'Not at Risk' 'At Risk' 'At Risk' 'Not at Risk' 'At Risk'
#  'At Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk' 'At Risk'
#  'At Risk' 'At Risk' 'Not at Risk' 'At Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'Not at Risk' 'At Risk' 'Not at Risk' 'At Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'At Risk' 'Not at Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk' 'At Risk'
#  'At Risk' 'At Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'Not at Risk' 'At Risk' 'At Risk' 'At Risk' 'Not at Risk'
#  'Not at Risk']

# %%
print(f"Expected Result{Y_test}")
# Out:
# Expected Result['Not at Risk' 'Not at Risk' 'At Risk' 'At Risk' 'Not at Risk' 'At Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk' 'At Risk'
#  'Not at Risk' 'At Risk' 'At Risk' 'Not at Risk' 'At Risk' 'Not at Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk' 'At Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk'
#  'At Risk' 'At Risk' 'At Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'At Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'At Risk' 'At Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'At Risk' 'At Risk'
#  'Not at Risk' 'At Risk' 'At Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'At Risk' 'At Risk'
#  'Not at Risk' 'Not at Risk' 'At Risk' 'At Risk' 'At Risk' 'Not at Risk'
#  'Not at Risk' 'At Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk'
#  'At Risk' 'Not at Risk' 'At Risk' 'At Risk' 'Not at Risk' 'Not at Risk'
#  'At Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'Not at Risk' 'At Risk' 'At Risk' 'At Risk' 'Not at Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'At Risk' 'At Risk'
#  'Not at Risk' 'At Risk' 'At Risk' 'Not at Risk' 'Not at Risk' 'At Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk'
#  'At Risk' 'Not at Risk' 'At Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk' 'At Risk'
#  'At Risk' 'Not at Risk' 'At Risk' 'At Risk' 'At Risk' 'At Risk'
#  'Not at Risk' 'At Risk' 'At Risk' 'At Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'At Risk' 'Not at Risk'
#  'Not at Risk' 'At Risk' 'Not at Risk' 'At Risk' 'At Risk' 'Not at Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk' 'At Risk'
#  'At Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk' 'At Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'At Risk' 'Not at Risk' 'At Risk' 'Not at Risk' 'At Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk' 'At Risk'
#  'Not at Risk' 'At Risk' 'At Risk' 'At Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk' 'At Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'At Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'At Risk' 'Not at Risk' 'Not at Risk' 'At Risk'
#  'Not at Risk' 'At Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'Not at Risk' 'At Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'At Risk' 'Not at Risk'
#  'At Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk' 'At Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'At Risk' 'At Risk' 'Not at Risk' 'Not at Risk' 'At Risk'
#  'At Risk' 'Not at Risk' 'At Risk' 'Not at Risk' 'Not at Risk' 'At Risk'
#  'Not at Risk' 'At Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk'
#  'At Risk' 'At Risk' 'At Risk' 'Not at Risk' 'Not at Risk' 'At Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'Not at Risk' 'At Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'Not at Risk' 'At Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'At Risk' 'Not at Risk'
#  'Not at Risk' 'At Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk'
#  'At Risk' 'At Risk' 'At Risk' 'Not at Risk' 'At Risk' 'Not at Risk'
#  'At Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk' 'At Risk'
#  'Not at Risk' 'At Risk' 'Not at Risk' 'At Risk' 'At Risk' 'Not at Risk'
#  'At Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'Not at Risk' 'At Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'At Risk' 'Not at Risk'
#  'Not at Risk' 'At Risk' 'Not at Risk' 'At Risk' 'Not at Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'At Risk' 'Not at Risk'
#  'Not at Risk' 'At Risk' 'At Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'Not at Risk' 'At Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'At Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk'
#  'At Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk' 'At Risk' 'At Risk'
#  'At Risk' 'Not at Risk' 'At Risk' 'At Risk' 'At Risk' 'Not at Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'Not at Risk' 'At Risk' 'At Risk' 'Not at Risk' 'At Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'Not at Risk' 'At Risk' 'Not at Risk' 'At Risk' 'At Risk'
#  'At Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk'
#  'At Risk' 'At Risk' 'At Risk' 'Not at Risk' 'Not at Risk' 'Not at Risk'
#  'Not at Risk' 'Not at Risk' 'At Risk' 'At Risk' 'At Risk' 'Not at Risk'
#  'Not at Risk']

# %%
from sklearn.metrics import accuracy_score
accuracy_score(predictions,Y_test)
# Out:
# 0.8938679245283019

# %%
data.head(2)
# Out:
#    gender  age  currentSmoker  cigsPerDay  BPMeds  diabetes  totChol  sysBP  \
# 0       1   39              0           0       0         0      195  106.0
# 1       0   46              0           0       0         0      250  121.0
#
#    diaBP    BMI  heartRate  glucose         Risk
# 0   70.0  26.97         80       77  Not at Risk
# 1   81.0  28.73         95       76  Not at Risk

# %%
data = [[0,90,0,0,20,1,200,190,90,21,23,89]]
data = model.predict(data)
print(f"You are {data}  of getting Hypertension")
# Out:
# You are ['At Risk']  of getting Hypertension
